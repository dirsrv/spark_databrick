# %%
print("Hello")
# Out:
# Hello

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=3352051324416570#setting/sparkui/0110-151749-elqe9eli/driver-7727580038332996158">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[8]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
dbutils.fs.ls("/")
# Out:
# Out[3]: [FileInfo(path='dbfs:/databricks-datasets/', name='databricks-datasets/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-results/', name='databricks-results/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/datalake/', name='datalake/', size=0, modificationTime=0)]

# %%
dbutils.fs.mkdirs("/datalake/raw")
# Out:
# Out[4]: True

# %%
dbutils.fs.mkdirs("/datalake/curated")
# Out:
# Out[5]: True

# %%
dbutils.fs.mkdirs("/datalake/serving")
# Out:
# Out[6]: True

# %%
dbutils.fs.ls("/datalake")
# Out:
# Out[7]: [FileInfo(path='dbfs:/datalake/curated/', name='curated/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/datalake/raw/', name='raw/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/datalake/serving/', name='serving/', size=0, modificationTime=0)]
